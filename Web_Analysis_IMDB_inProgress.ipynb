# %%
import pandas as pd
from urllib.parse import urlparse
import numpy as np
import nltk.data
from requests_html import HTMLSession
import requests
from bs4 import BeautifulSoup
import re

# %%
def scrape_imdb(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    i = 0 # Just for tracking
    
    movies = []
    for movie in soup.find_all("div", class_="lister-item mode-advanced"):
        ''' Just for tracking
        i+=1
        if i<=0:
            print(i)
            print(soup.find_all("div", class_="lister-item mode-advanced")[0])
        '''
        
        title = movie.find("h3").text

        certificate = movie.find("span", class_="certificate")
        if certificate is not None:
            certificate = certificate.text
        else:
            certificate = "N/A"

        runtime = movie.find("span", class_="runtime")
        if runtime is not None:
            runtime = runtime.text
        else:
            runtime = "N/A"
        
        genre = movie.find("span", class_="genre")
        if genre is not None:
            genre = genre.text
        else:
            genre = "N/A"
        
        rating = movie.find("strong")
        if rating is not None:
            rating = rating.text
        else:
            rating = "N/A"
        
        metascore = movie.find("span", class_="metascore mixed")
        if metascore is not None:
            metascore = metascore.text
        else:
            metascore = "N/A"
        
        brief = movie.find("p", class_="text-muted").text
        print(brief)

        movies.append({
            "title": title,
            "certificate": certificate,
            "runtime": runtime,
            "genre": genre,
            "rating": rating,
            "metascore": metascore
        })

    return movies

if __name__ == "__main__":
    movies = scrape_imdb("https://www.imdb.com/search/title?title_type=feature")

    for movie in movies:
        print(movie["title"], movie["certificate"], movie["runtime"], movie["genre"], movie["rating"], movie["metascore"])
# Out:
# 1
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt9603212"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt9603212/"> <img alt="Mission: Impossible - Dead Reckoning Part One" class="loadlate" data-tconst="tt9603212" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzFiZjc1YzctMDY3Zi00NGE5LTlmNWEtN2Q3OWFjYjY1NGM2XkEyXkFqcGdeQXVyMTUyMTUzNjQ0._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt9603212/">Mission: Impossible - Dead Reckoning Part One</a>
# <span class="lister-item-year text-muted unbold">(2023)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">PG-13</span>
# <span class="ghost">|</span>
# <span class="runtime">163 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt9603212" id="urv_tt9603212">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt9603212">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt9603212|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (53,743 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="53743" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt9603212/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">81        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# Ethan Hunt and his IMF team must track down a dangerous weapon before it falls into the wrong hands.</p>
# <p class="">
#     Director:
# <a href="/name/nm0003160/">Christopher McQuarrie</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000129/">Tom Cruise</a>,
# <a href="/name/nm2017943/">Hayley Atwell</a>,
# <a href="/name/nm0000609/">Ving Rhames</a>,
# <a href="/name/nm0670408/">Simon Pegg</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="53743" name="nv">53,743</span>
# </p>
# </div>
# </div>
#
# PG-13
# |
# 163 min
# |
#
# Action, Adventure, Thriller
#
# 2
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt9603212"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt9603212/"> <img alt="Mission: Impossible - Dead Reckoning Part One" class="loadlate" data-tconst="tt9603212" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzFiZjc1YzctMDY3Zi00NGE5LTlmNWEtN2Q3OWFjYjY1NGM2XkEyXkFqcGdeQXVyMTUyMTUzNjQ0._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt9603212/">Mission: Impossible - Dead Reckoning Part One</a>
# <span class="lister-item-year text-muted unbold">(2023)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">PG-13</span>
# <span class="ghost">|</span>
# <span class="runtime">163 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.1" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.1</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt9603212" id="urv_tt9603212">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt9603212">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt9603212|imdb|8.1|8.1|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.1/10 (53,743 votes) - click stars to rate">
# <meta content="8.1" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="53743" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 113.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">8.1</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt9603212/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">81        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# Ethan Hunt and his IMF team must track down a dangerous weapon before it falls into the wrong hands.</p>
# <p class="">
#     Director:
# <a href="/name/nm0003160/">Christopher McQuarrie</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0000129/">Tom Cruise</a>,
# <a href="/name/nm2017943/">Hayley Atwell</a>,
# <a href="/name/nm0000609/">Ving Rhames</a>,
# <a href="/name/nm0670408/">Simon Pegg</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="53743" name="nv">53,743</span>
# </p>
# </div>
# </div>
#
# PG-13
# |
# 131 min
# |
#
# Action, Biography, Drama
#
#
# R
# |
# 180 min
# |
#
# Biography, Drama, History
#
#
# PG-13
# |
# 114 min
# |
#
# Adventure, Comedy, Fantasy
#
#
# R
# |
# 95 min
# |
#
# Action, Comedy, Crime
#
#
# PG-13
# |
# 154 min
# |
#
# Action, Adventure
#
#
#
# Adventure, Comedy, Family
# |
# Post-production
#
#
# PG-13
# |
# 150 min
# |
#
# Action, Adventure, Comedy
#
#
# R
# |
# 158 min
# |
#
# Action, Adventure, Biography
# |
# Completed
#
#
# PG-13
# |
# 105 min
# |
#
# Comedy, Drama, Romance
#
#
# PG-13
# |
# 107 min
# |
#
# Horror, Mystery, Thriller
#
#
# PG-13
# |
# 127 min
# |
#
# Action, Adventure, Sci-Fi
#
#
# R
# |
# 103 min
# |
#
# Comedy, Romance
#
#
# PG
# |
# 140 min
# |
#
# Animation, Action, Adventure
#
#
# R
# |
# 206 min
# |
#
# Crime, Drama, History
#
#
# R
# |
# 95 min
# |
#
# Comedy
#
#
# PG-13
# |
# 147 min
# |
#
# Action, Adventure, Thriller
#
#
# PG-13
# |
# 93 min
# |
#
# Action, Adventure, Drama
#
#
# PG-13
# |
# 144 min
# |
#
# Action, Adventure, Fantasy
#
#
# PG-13
# |
# 110 min
# |
#
# Action, Adventure, Thriller
#
#
#
# Action, Comedy, Sci-Fi
# |
# Filming
#
#
# PG
# |
# 101 min
# |
#
# Animation, Adventure, Comedy
#
#
# R
# |
# 122 min
# |
#
# Action, Thriller
#
#
# 117 min
# |
#
# Drama, Romance
#
#
# R
# |
# 169 min
# |
#
# Action, Crime, Thriller
#
#
# PG
# |
# 101 min
# |
#
# Animation, Action, Adventure
#
#
# PG-13
# |
# 194 min
# |
#
# Drama, Romance
#
#
# PG-13
# |
# 131 min
# |
#
# Action, Adventure, Thriller
#
#
# PG-13
# |
# 134 min
# |
#
# Action, Adventure, Comedy
#
#
# PG-13
# |
# 192 min
# |
#
# Action, Adventure, Fantasy
#
#
# PG-13
# |
#
# Action, Adventure, Sci-Fi
# |
# Completed
#
#
# TV-MA
# |
# 112 min
# |
#
# Horror, Mystery, Sci-Fi
#
#
# R
# |
# 123 min
# |
#
# Action, Thriller, War
#
#
# R
# |
# 96 min
# |
#
# Horror
#
#
# PG
# |
# 92 min
# |
#
# Animation, Adventure, Comedy
#
#
# PG-13
# |
# 122 min
# |
#
# Comedy, Drama, Family
# |
# Completed
#
#
# PG
# |
# 115 min
# |
#
# Action, Adventure
#
#
# PG
# |
# 135 min
# |
#
# Adventure, Family, Fantasy
#
#
# PG-13
# |
# 132 min
# |
#
# Action, Adventure, Thriller
#
#
# PG-13
# |
# 126 min
# |
#
# Action, Adventure, Thriller
#
#
# PG-13
# |
# 123 min
# |
#
# Action, Adventure, Thriller
#
#
#
# Horror
# |
# Post-production
#
#
# R
# |
# 105 min
# |
#
# Horror, Mystery, Thriller
#
#
# R
# |
# 97 min
# |
#
# Comedy, Horror, Thriller
#
#
# PG-13
# |
# 103 min
# |
#
# Horror, Mystery, Thriller
#
#
# TV-MA
# |
# 132 min
# |
#
# Drama, Romance
#
#
# R
# |
# 112 min
# |
#
# Comedy, Romance
# |
# Completed
#
#
# 165 min
# |
#
# Action, Thriller
# |
# Post-production
#
#
# PG-13
# |
# 169 min
# |
#
# Adventure, Drama, Sci-Fi
#
#
# R
# |
# 122 min
# |
#
# Horror, Mystery, Thriller
#
#
# 1.
# Mission: Impossible - Dead Reckoning Part One
# (2023)
#  PG-13 163 min
# Action, Adventure, Thriller             8.1 N/A
#
# 2.
# Sound of Freedom
# (2023)
#  PG-13 131 min
# Action, Biography, Drama             8.2 43
#
# 3.
# Oppenheimer
# (2023)
#  R 180 min
# Biography, Drama, History             N/A N/A
#
# 4.
# Barbie
# (I) (2023)
#  PG-13 114 min
# Adventure, Comedy, Fantasy             N/A N/A
#
# 5.
# The Out-Laws
# (2023)
#  R 95 min
# Action, Comedy, Crime             5.4 N/A
#
# 6.
# Indiana Jones and the Dial of Destiny
# (2023)
#  PG-13 154 min
# Action, Adventure             6.9 58
#
# 7.
# Wonka
# (2023)
#  N/A N/A
# Adventure, Comedy, Family             N/A N/A
#
# 8.
# Guardians of the Galaxy Vol. 3
# (2023)
#  PG-13 150 min
# Action, Adventure, Comedy             8.1 N/A
#
# 9.
# Napoleon
# (2023)
#  R 158 min
# Action, Adventure, Biography             N/A N/A
#
# 10.
# Asteroid City
# (2023)
#  PG-13 105 min
# Comedy, Drama, Romance             6.9 N/A
#
# 11.
# Insidious: The Red Door
# (2023)
#  PG-13 107 min
# Horror, Mystery, Thriller             6.0 45
#
# 12.
# Transformers: Rise of the Beasts
# (2023)
#  PG-13 127 min
# Action, Adventure, Sci-Fi             6.3 42
#
# 13.
# No Hard Feelings
# (2023)
#  R 103 min
# Comedy, Romance             6.7 59
#
# 14.
# Spider-Man: Across the Spider-Verse
# (2023)
#  PG 140 min
# Animation, Action, Adventure             8.9 N/A
#
# 15.
# Killers of the Flower Moon
# (2023)
#  R 206 min
# Crime, Drama, History             N/A N/A
#
# 16.
# Joy Ride
# (2023)
#  R 95 min
# Comedy             7.0 N/A
#
# 17.
# Mission: Impossible - Fallout
# (2018)
#  PG-13 147 min
# Action, Adventure, Thriller             7.7 N/A
#
# 18.
# 65
# (2023)
#  PG-13 93 min
# Action, Adventure, Drama             5.4 40
#
# 19.
# The Flash
# (2023)
#  PG-13 144 min
# Action, Adventure, Fantasy             7.1 56
#
# 20.
# Mission: Impossible
# (1996)
#  PG-13 110 min
# Action, Adventure, Thriller             7.1 59
#
# 21.
# Deadpool 3
# (2024)
#  N/A N/A
# Action, Comedy, Sci-Fi             N/A N/A
#
# 22.
# Elemental
# (2023)
#  PG 101 min
# Animation, Adventure, Comedy             7.1 58
#
# 23.
# Extraction II
# (2023)
#  R 122 min
# Action, Thriller             7.1 57
#
# 24.
# My Fault
# (2023)
#  N/A 117 min
# Drama, Romance             6.3 N/A
#
# 25.
# John Wick: Chapter 4
# (2023)
#  R 169 min
# Action, Crime, Thriller             7.8 N/A
#
# 26.
# Nimona
# (2023)
#  PG 101 min
# Animation, Action, Adventure             7.6 N/A
#
# 27.
# Titanic
# (1997)
#  PG-13 194 min
# Drama, Romance             7.9 N/A
#
# 28.
# Mission: Impossible - Rogue Nation
# (2015)
#  PG-13 131 min
# Action, Adventure, Thriller             7.4 N/A
#
# 29.
# Dungeons & Dragons: Honor Among Thieves
# (2023)
#  PG-13 134 min
# Action, Adventure, Comedy             7.3 N/A
#
# 30.
# Avatar: The Way of Water
# (2022)
#  PG-13 192 min
# Action, Adventure, Fantasy             7.6 N/A
#
# 31.
# Blue Beetle
# (2023)
#  PG-13 N/A
# Action, Adventure, Sci-Fi             N/A N/A
#
# 32.
# Bird Box: Barcelona
# (2023)
#  TV-MA 112 min
# Horror, Mystery, Sci-Fi             5.4 45
#
# 33.
# The Covenant
# (2023)
#  R 123 min
# Action, Thriller, War             7.5 N/A
#
# 34.
# Evil Dead Rise
# (2023)
#  R 96 min
# Horror             6.6 N/A
#
# 35.
# The Super Mario Bros. Movie
# (2023)
#  PG 92 min
# Animation, Adventure, Comedy             7.1 46
#
# 36.
# Haunted Mansion
# (2023)
#  PG-13 122 min
# Comedy, Drama, Family             N/A N/A
#
# 37.
# Raiders of the Lost Ark
# (1981)
#  PG 115 min
# Action, Adventure             8.4 N/A
#
# 38.
# The Little Mermaid
# (I) (2023)
#  PG 135 min
# Adventure, Family, Fantasy             7.2 59
#
# 39.
# Mission: Impossible - Ghost Protocol
# (2011)
#  PG-13 132 min
# Action, Adventure, Thriller             7.4 N/A
#
# 40.
# Mission: Impossible III
# (2006)
#  PG-13 126 min
# Action, Adventure, Thriller             6.9 N/A
#
# 41.
# Mission: Impossible II
# (2000)
#  PG-13 123 min
# Action, Adventure, Thriller             6.1 59
#
# 42.
# Five Nights at Freddy's
# (2023)
#  N/A N/A
# Horror             N/A N/A
#
# 43.
# X
# (II) (2022)
#  R 105 min
# Horror, Mystery, Thriller             6.6 N/A
#
# 44.
# The Blackening
# (2022)
#  R 97 min
# Comedy, Horror, Thriller             6.1 N/A
#
# 45.
# Insidious
# (I) (2010)
#  PG-13 103 min
# Horror, Mystery, Thriller             6.8 52
#
# 46.
# Lust Stories 2
# (2023)
#  TV-MA 132 min
# Drama, Romance             6.2 N/A
#
# 47.
# Red, White & Royal Blue
# (2023)
#  R 112 min
# Comedy, Romance             N/A N/A
#
# 48.
# Jawan
# (2023)
#  N/A 165 min
# Action, Thriller             N/A N/A
#
# 49.
# Interstellar
# (2014)
#  PG-13 169 min
# Adventure, Drama, Sci-Fi             8.7 N/A
#
# 50.
# Scream VI
# (2023)
#  R 122 min
# Horror, Mystery, Thriller             6.6 N/A
